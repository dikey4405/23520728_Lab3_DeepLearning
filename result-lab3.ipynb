# %%
# !git clone https://github.com/dikey4405/23520728_Lab3_DeepLearning.git
# Out:
# Cloning into '23520728_Lab3_DeepLearning'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 73 (delta 33), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 31.13 KiB | 15.57 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd 23520728_Lab3_DeepLearning
# Out:
# /kaggle/working/23520728_Lab3_DeepLearning/23520728_Lab3_DeepLearning/23520728_Lab3_DeepLearning/23520728_Lab3_DeepLearning/23520728_Lab3_DeepLearning/23520728_Lab3_DeepLearning

# %% [markdown]
# ## Bài 1

# %%
# !python train_vsfc.py
# Out:
# Loading vocab ...
# Loading dataset ...
# Creating dataloader ...
# Building model ...
# ...
# Epoch 1 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 325.18it/s]
# Precision: 0.3539
# Recall: 0.4008
# F1 Score: 0.3758
# ----------------------------------
# ...
# Epoch 2 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 330.61it/s]
# Precision: 0.5986
# Recall: 0.6156
# F1 Score: 0.6052
# ----------------------------------
# ...
# Epoch 3 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 327.17it/s]
# Precision: 0.5936
# Recall: 0.6094
# F1 Score: 0.6010
# ----------------------------------
# ...
# Epoch 4 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 328.30it/s]
# Precision: 0.6236
# Recall: 0.6261
# F1 Score: 0.6159
# ----------------------------------
# ...
# Epoch 5 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 323.16it/s]
# Precision: 0.6141
# Recall: 0.5049
# F1 Score: 0.5237
# ----------------------------------
# ...

# %% [markdown]
# ## Bài 2

# %%
# !python train_vsfc_GRU.py
# Out:
# Loading vocab ...
# Loading dataset ...
# Creating dataloader ...
# Building model ...
# ...
# Epoch 1 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 314.83it/s]
# Precision: 0.5816
# Recall: 0.6181
# F1 Score: 0.5909
# ----------------------------------
# ...
# Epoch 2 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 319.44it/s]
# Precision: 0.7962
# Recall: 0.6022
# F1 Score: 0.6495
# ----------------------------------
# ...
# Epoch 3 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 317.18it/s]
# Precision: 0.8342
# Recall: 0.6588
# F1 Score: 0.6746
# ----------------------------------
# ...
# Epoch 4 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 310.46it/s]
# Precision: 0.7769
# Recall: 0.7615
# F1 Score: 0.7562
# ----------------------------------
# ...
# Epoch 5 - Evaluation: 100%|████████████████████| 99/99 [00:00<00:00, 314.96it/s]
# Precision: 0.8146
# Recall: 0.7376
# F1 Score: 0.7654
# ----------------------------------
# ...

# %% [markdown]
# ## Bài 3

# %%
# !python train_PhoNER.py
# Out:
# Device being used: cuda
# Loading vocab ...
# Building vocab from: /kaggle/input/phoner/train_word.json
# File /kaggle/input/phoner/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Vocab size: 4741
# Num tags: 20
# Loading dataset ...
# Loading data from: /kaggle/input/phoner/train_word.json
# File /kaggle/input/phoner/train_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Loading data from: /kaggle/input/phoner/dev_word.json
# File /kaggle/input/phoner/dev_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Loading data from: /kaggle/input/phoner/test_word.json
# File /kaggle/input/phoner/test_word.json có vẻ là JSON Lines. Đang chuyển sang chế độ đọc từng dòng...
# Creating dataloader ...
# Building Bi-LSTM NER model ...
# Starting training ...
# ...
# Epoch 1 - Evaluation: 100%|█████████████████████| 63/63 [00:00<00:00, 79.27it/s]
# Precision: 0.1884
# Recall: 0.1833
# F1 Score: 0.1731
# ...

# %% [markdown]
# #
